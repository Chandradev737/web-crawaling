# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import defaultdict
# %matplotlib inline
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import csv
import requests

# %%
url = "https://www.ondoor.com"
html = urlopen(url)

# %%
page_src = soup(html, 'lxml')
type(page_src)
# Out:
# bs4.BeautifulSoup

# %%
page_src
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <title>Online Grocery Shopping | Free home delivery | Vegetables | Fruits | Cakes |  Flowers | Bhopal | Ondoor</title>
# <!--Let browser know website is optimized for mobile-->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://d1s2zprapij148.cloudfront.net/image/favicons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# ...

# %%
data = page_src.findAll('div',attrs={'class':'col l10 m9 s12'})
#data = page_src.findAll('li',attrs={'class':'navico'})
data
data1=data.pop(1)
data1
all_links = data1.find_all('a', href=re.compile("category"))
all_urls1 = []
#all_links = data1.find_all('a', href=re.compile("category"))
for link in all_links:
    all_urls1.append('https://www.ondoor.com/' + link.get("href"))
    #print(link.get("href"))
all_urls1
# Out:
# ['https://www.ondoor.com/category/fruits-vegetables/fruits',
#  'https://www.ondoor.com/category/fruits-vegetables/vegetables',
#  'https://www.ondoor.com/category/branded-foods/namkeen',
#  'https://www.ondoor.com/category/branded-foods/biscuits-and-cookies',
#  'https://www.ondoor.com/category/dairy-bread/dairy-products',
#  'https://www.ondoor.com/category/dairy-bread/bake-n-shake',
#  'https://www.ondoor.com/category/dairy-bread/dairy-products/paneer-tofu',
#  'https://www.ondoor.com/category/personal-care/personal-hygiene/hand-wash',
#  'https://www.ondoor.com/category/household/detergents-and-bars/liquid-detergent',
#  'https://www.ondoor.com/category/personal-care/hair-care/shampoo',
#  'https://www.ondoor.com/category/personal-care/hair-care/hair-conditioner',
#  'https://www.ondoor.com/category/personal-care/deos-perfumes',
#  'https://www.ondoor.com/category/beverages/tea-coffee',
#  'https://www.ondoor.com/category/beverages/fruit-drinks-juices',
# ...

# %%
product_name = []
product_price = []
product_image = []
product_description = []
all_prod_link = []

# %%
for link in all_urls1:
    response = requests.get(link)
    n_page_src = soup(response.text, 'html.parser')
    
    container1 = n_page_src.findAll("div", {"class": "prod-name"})
    container2 = n_page_src.findAll("div", {"class": "prod-ratebox"})
    container3 = n_page_src.findAll("div", {"class": "prod-thumb"})
    container4 = n_page_src.findAll("div", {"class": "prod-thumb"})
    
    container=[container1,container2,container3,container4]
    
    container11 = container[0]
    container12 = container[1]
    container13 = container[2]
    container14 = container[3]
    
    
    
    for container11 in container[0]:
        prod_name=container11.findAll('h6')
        p1=(prod_name[0].text)
        product_name.append(p1)
    for container12 in container[1]:
        prod_price=container12.findAll('span')
        p2=(prod_price[0].text)
        product_price.append(p2)
    for container13 in container[2]:
        prod_img=container13.find('img')
        p3=(prod_img.get("src"))
        product_image.append(p3)
    for container14 in container[3]:
        prod_link=container14.find('a')
        all_prod_link.append('https://www.ondoor.com/' + prod_link.get("href"))

# %%
for link in all_prod_link:
    next_response = requests.get(link)
    third_page_src = soup(response.text, 'html.parser')
    x=third_page_src.findAll("div", {"id": "description"})
    p4 = x[0].text
    product_description.append(p4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3508bf5d502e> in <module>()
# ----> 1 for link in all_prod_link:
#       2     next_response = requests.get(link)
#       3     third_page_src = soup(response.text, 'html.parser')
#       4     x=third_page_src.findAll("div", {"id": "description"})
#       5     p4 = x[0].text
#
# NameError: name 'all_prod_link' is not defined

# %%
len(all_prod_link)
# Out:
# 676
